# %%
enroncsv = "../experiments/data/enron.csv"
metadataHeaders = '../experiments/data/metadataHeaders.csv'

# %%
import pandas as pd

columns = pd.read_csv(metadataHeaders, sep=',').columns.tolist()
columns
# Out:
# ['Filename',
#  'Person',
#  'Directory',
#  'Message-ID',
#  'Date',
#  'From',
#  'To',
#  'Subject',
#  'Cc',
#  'Time',
#  'Attendees',
#  'Re',
#  'Mime-Version',
#  'Content-Type',
#  'Content-Transfer-Encoding',
#  'Bcc',
#  'X-From',
#  'X-To',
#  'X-cc',
#  'X-bcc',
#  'X-Folder',
#  'X-Origin',
#  'X-FileName']

# %%
df = pd.read_csv(enroncsv, names=columns, sep='|', low_memory=False)

print("-- DONE --")
# Out:
# -- DONE --

# %%
import hashlib

def hashFunc(val):
    try:
        return hashlib.sha256(val.encode('utf-8')).hexdigest()
    except Exception:
        pass

df.Person = df.Person.apply(hashFunc)
df.Directory = df.Directory.apply(hashFunc)
df.To = df.To.apply(hashFunc)
df.From = df.From.apply(hashFunc)
df['X-To'] = df['X-To'].apply(hashFunc)
df['X-From'] = df['X-From'].apply(hashFunc)
df.Cc = df.Cc.apply(hashFunc)
df.Bcc = df.Bcc.apply(hashFunc)
df['X-cc'] = df['X-cc'].apply(hashFunc)
df['X-bcc'] = df['X-From'].apply(hashFunc)
df['X-Folder'] = df['X-Folder'].apply(hashFunc)
df['X-Origin'] = df['X-Origin'].apply(hashFunc)
df['X-FileName'] = df['X-FileName'].apply(hashFunc)

df.head()
# Out:
#   Filename                                             Person  \
# 0    1076.  99ae8dc8be18fe99154f6cdebf7094c478bdbac424e5e8...
# 1    1126.  99ae8dc8be18fe99154f6cdebf7094c478bdbac424e5e8...
# 2     934.  99ae8dc8be18fe99154f6cdebf7094c478bdbac424e5e8...
# 3    1657.  99ae8dc8be18fe99154f6cdebf7094c478bdbac424e5e8...
# 4    1121.  99ae8dc8be18fe99154f6cdebf7094c478bdbac424e5e8...
#
#                                            Directory  \
# 0  988f30ddecf0fdd099c5c176bab6bf4a45f780e329e32c...
# 1  988f30ddecf0fdd099c5c176bab6bf4a45f780e329e32c...
# 2  988f30ddecf0fdd099c5c176bab6bf4a45f780e329e32c...
# 3  988f30ddecf0fdd099c5c176bab6bf4a45f780e329e32c...
# 4  988f30ddecf0fdd099c5c176bab6bf4a45f780e329e32c...
#
#                                       Message-ID  \
# 0  <24986559.1075840719297.JavaMail.evans@thyme>
# 1   <7461681.1075840720553.JavaMail.evans@thyme>
# 2  <28617320.1075840715596.JavaMail.evans@thyme>
# 3  <27141378.1075840735658.JavaMail.evans@thyme>
# 4   <9976025.1075840720405.JavaMail.evans@thyme>
#
#                               Date  \
# 0  Thu, 22 Feb 2001 13:39:00 -0800
# 1  Tue, 06 Feb 2001 06:33:00 -0800
# 2  Sat, 03 Mar 2001 05:37:00 -0800
# 3  Fri, 27 Oct 2000 03:26:00 -0700
# 4  Wed, 07 Feb 2001 16:29:00 -0800
#
#                                                 From  \
# 0  2a0c86a8fa25e09e3702b5442b2a35f7b59011badd551e...
# 1  b040efe6d14b85c42506c73dc4a01e93296934f44e2865...
# 2  2a0c86a8fa25e09e3702b5442b2a35f7b59011badd551e...
# 3  576596661a47e3b46215239a8f2b30b34685cdcbb6c738...
# 4  9192a797b370e75a3f85fb2abf07bc7a49418b96f446b2...
#
#                                                   To  \
# 0  2a0c86a8fa25e09e3702b5442b2a35f7b59011badd551e...
# 1  5a21f2a26629abbbf9f84a23ccfee58d262aa014a46292...
# 2  2a0c86a8fa25e09e3702b5442b2a35f7b59011badd551e...
# 3  573f71ae4c5bf44a1cbe5be5d27b0c1edb46af443a1b0f...
# 4  ccdfe0ac2b06a3d61939ca0f89078e6c68acc196749bc0...
#
#                                              Subject  \
# 0  Start Date: 2/22/01; HourAhead hour: 22;  <COD...
# 1                            DMS 6572 PPLMON 1-23-01
# 2  Start Date: 3/3/01; HourAhead hour: 14;  <CODE...
# 3  DJ House Votes, But FERC Unswayed On Calif Pwr...
# 4                    XMS (Expense Management System)
#
#                                                   Cc Time  \
# 0  8b0c9c887fd4994d58498c1d37053fd0b2a2faa3a506c1...  NaN
# 1  a1f4e0320c1e99c8e334c73c40a4768fe5f4734faedaa2...  NaN
# 2  8b0c9c887fd4994d58498c1d37053fd0b2a2faa3a506c1...  NaN
# 3                                               None  NaN
# 4                                               None  NaN
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#                            Content-Type Content-Transfer-Encoding  \
# 0        text/plain; charset="us-ascii"                      7bit
# 1        text/plain; charset="us-ascii"                      7bit
# 2        text/plain; charset="us-ascii"                      7bit
# 3        text/plain; charset="us-ascii"                      7bit
# 4  text/plain; charset="ANSI_X3.4-1968"          quoted-printable
#
#                                                  Bcc  \
# 0  8b0c9c887fd4994d58498c1d37053fd0b2a2faa3a506c1...
# 1  a1f4e0320c1e99c8e334c73c40a4768fe5f4734faedaa2...
# 2  8b0c9c887fd4994d58498c1d37053fd0b2a2faa3a506c1...
# 3                                               None
# 4                                               None
#
#                                               X-From  \
# 0  6698d13e4f54f276ba8357dc6715d70fdcc661e89009fd...
# 1  26d0c1b19b6f2a55a205f27e5904ebd3c90b46079b2377...
# 2  6698d13e4f54f276ba8357dc6715d70fdcc661e89009fd...
# 3  452539bc3bad3984b94e83b899fb12efae6b2f5d47ab26...
# 4  6cf53ae7e49c8fb4ba7695bc184140e6e80fd8e04aa2c0...
#
#                                                 X-To  \
# 0  2a0c86a8fa25e09e3702b5442b2a35f7b59011badd551e...
# 1  cba879e15fe8d508fc8634dff11cba1cd6279c0778b3bb...
# 2  2a0c86a8fa25e09e3702b5442b2a35f7b59011badd551e...
# 3  680407d445b75853816899992f0d1b593462d1977e0a7f...
# 4  55119a0f473f8ead1cb3a2ac17c587d2c3b6e1eadc1fa9...
#
#                                                 X-cc  \
# 0  e0fd4dd45bf54cab9f2973d9bc492a99e0c3b3b0a45000...
# 1  962deed23add9c74d7c28584cea44e86d74820afe3dfc7...
# 2  e0fd4dd45bf54cab9f2973d9bc492a99e0c3b3b0a45000...
# 3                                               None
# 4                                               None
#
#                                                X-bcc  \
# 0  ec47b0540faa008f40d44d041100f9450135c9710834d4...
# 1  0e061cf7288ec606df40545618b383a165db098c696cdb...
# 2  ec47b0540faa008f40d44d041100f9450135c9710834d4...
# 3  fc2edcdac0a8be29904ee89163b1d6f3d69eea337cb0a1...
# 4  a5b16cb18647497cc3039b79a1f19d45e522a466ce7690...
#
#                                             X-Folder  \
# 0  6936530d752a06e7bde2e70a72a5766eeea39754a0d6be...
# 1  6936530d752a06e7bde2e70a72a5766eeea39754a0d6be...
# 2  6936530d752a06e7bde2e70a72a5766eeea39754a0d6be...
# 3  6936530d752a06e7bde2e70a72a5766eeea39754a0d6be...
# 4  6936530d752a06e7bde2e70a72a5766eeea39754a0d6be...
#
#                                             X-Origin  \
# 0  6eac701fb015a578e2538d2f7ba80d7fabf8406c6a75fc...
# 1  6eac701fb015a578e2538d2f7ba80d7fabf8406c6a75fc...
# 2  6eac701fb015a578e2538d2f7ba80d7fabf8406c6a75fc...
# 3  6eac701fb015a578e2538d2f7ba80d7fabf8406c6a75fc...
# 4  6eac701fb015a578e2538d2f7ba80d7fabf8406c6a75fc...
#
#                                           X-FileName
# 0  2439fd5475cfc946403eeb61832ee5bef1d86fdc68fb63...
# 1  2439fd5475cfc946403eeb61832ee5bef1d86fdc68fb63...
# 2  2439fd5475cfc946403eeb61832ee5bef1d86fdc68fb63...
# 3  2439fd5475cfc946403eeb61832ee5bef1d86fdc68fb63...
# 4  2439fd5475cfc946403eeb61832ee5bef1d86fdc68fb63...
#
# [5 rows x 23 columns]

# %%
df.to_csv('../experiments/data/anon.csv', sep='|', header=False)
print("-- DONE --")
# Out:
# -- DONE --
